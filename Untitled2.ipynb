# %%
import xlrd

# %%
import xlrd
book = xlrd.open_workbook('./parameters/PR_001_Daten.xlsx')

# %%
s=book.sheet_by_index(0)

# %%
s.col(2)
# Out:
# [text:u'R51',
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:2.5,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.0,
#  number:3.5,
#  number:3.5,
#  number:3.5,
#  number:3.5,
#  number:3.5,
#  number:3.5,
#  number:3.5,
#  number:3.5,
#  number:3.5,
#  number:3.5,
#  number:3.5,
#  number:3.5,
#  number:3.5,
# ...
